# %% [markdown]
# <a href="https://colab.research.google.com/github/AvishekGolder/Machine-Learning-Lab/blob/main/blood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &>/dev/null
print("Installed")
# Out:
# Installed

# %%
from pycaret.datasets import get_data
x= get_data("index")
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
x=get_data("blood")
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %%
print(x.to_string())
# Out:
#      Recency  Frequency  Monetary  Time  Class
# 0          2         50     12500    98      1
# 1          0         13      3250    28      1
# 2          1         16      4000    35      1
# 3          2         20      5000    45      1
# 4          1         24      6000    77      0
# 5          4          4      1000     4      0
# 6          2          7      1750    14      1
# 7          1         12      3000    35      0
# 8          2          9      2250    22      1
# 9          5         46     11500    98      1
# 10         4         23      5750    58      0
# 11         0          3       750     4      0
# 12         2         10      2500    28      1
# 13         1         13      3250    47      0
# 14         2          6      1500    15      1
# 15         2          5      1250    11      1
# 16         2         14      3500    48      1
# 17         2         15      3750    49      1
# 18         2          6      1500    15      1
# ...

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
x = get_data("blood")
s = setup(data=x, target="Class", silent=True)
adaModel = create_model('ada')
#plot_model(adaModel, plot="confusion_matrix")
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7170  0.6402  0.0833  0.2000  0.1176 -0.0179 -0.0204
# 1       0.7736  0.7409  0.0833  0.5000  0.1429  0.0836  0.1295
# 2       0.7547  0.6250  0.0833  0.3333  0.1333  0.0470  0.0626
# 3       0.7885  0.9208  0.0833  1.0000  0.1538  0.1227  0.2557
# 4       0.7885  0.4052  0.0833  1.0000  0.1538  0.1227  0.2557
# 5       0.8077  0.7361  0.2727  0.6000  0.3750  0.2798  0.3102
# 6       0.7692  0.7284  0.1818  0.4000  0.2500  0.1357  0.1505
# 7       0.8269  0.6064  0.2727  0.7500  0.4000  0.3237  0.3806
# 8       0.7885  0.6497  0.3636  0.5000  0.4211  0.2956  0.3012
# 9       0.7692  0.6441  0.2727  0.4286  0.3333  0.2020  0.2096
# Mean    0.7784  0.6697  0.1780  0.5712  0.2481  0.1595  0.2035
# Std     0.0284  0.1240  0.1031  0.2559  0.1164  0.1072  0.1166
# INFO:logs:create_model_container: 1
# INFO:logs:master_model_container: 1
# INFO:logs:display_container: 2
# ...

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
x = get_data("blood")
s = setup(data=x, target="Class", silent=True)
adaModel = create_model('ada')
plot_model(adaModel, plot="confusion_matrix")
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................

# %%
best_model = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ada                  Ada Boost Classifier    0.8011  0.6753  0.3045  0.6374
# qda       Quadratic Discriminant Analysis    0.7784  0.7355  0.1583  0.6233
# gbc          Gradient Boosting Classifier    0.7781  0.6809  0.3045  0.5444
# nb                            Naive Bayes    0.7726  0.7308  0.1417  0.5667
# lr                    Logistic Regression    0.7688  0.7483  0.0750  0.5250
# rf               Random Forest Classifier    0.7688  0.6865  0.3301  0.5223
# lda          Linear Discriminant Analysis    0.7688  0.7448  0.0750  0.5083
# ridge                    Ridge Classifier    0.7687  0.0000  0.0583  0.4250
# dummy                    Dummy Classifier    0.7687  0.5000  0.0000  0.0000
# lightgbm  Light Gradient Boosting Machine    0.7667  0.6839  0.3378  0.5081
# knn                K Neighbors Classifier    0.7477  0.6189  0.2301  0.4886
# ...
